# %% [markdown]
# ## Tạo Tensor cơ bản

# %%
import torch

print(torch.__version__)
a = torch.tensor(
[[1, 2, 3],
[4, 5, 6]],
dtype=torch.int32
)
print(a)
# Out:
# 2.14.0+cpu
# tensor([[1, 2, 3],
#         [4, 5, 6]], dtype=torch.int32)
